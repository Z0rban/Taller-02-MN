# %% [markdown]
# # Taller 2

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
from scipy.optimize import newton

x0 = 100
points = []
x_r = newton(
    f, x0, args=(points, True), maxiter=100
)  # Método secante
# Out:
# f(100.0) = 970099.0
# f(100.01010000000001) = 970395.9803980006
# f(67.00792386980214) = 287465.54571529943
# f(53.116335372259854) = 141447.59273483977
# f(39.65955343460801) = 57699.74450824955
# f(30.388236067683557) = 25320.914914632634
# f(23.137873990336278) = 10803.174516522931
# f(17.742617932460977) = 4657.725983130829
# f(13.65347387896111) = 1998.6458316465025
# f(10.579948354366646) = 858.043795817009
# f(8.267818948297682) = 367.35922412035336
# f(6.536804537670478) = 156.66380304361124
# f(5.249698727272358) = 66.24990348675587
# f(4.306584492248163) = 27.539375882553202
# f(3.6356358117218313) = 11.037373198988304
# f(3.1868714328556598) = 4.084765647739281
# f(2.923215343365569) = 1.2670760212328207
# f(2.804652849575538) = 0.26803700410227016
# f(2.772843145360331) = 0.02631152581509344
# f(2.7693806975473843) = 0.0006530032799583196
# f(2.769292579076204) = 1.6618166540638413e-06
# f(2.7692923542528955) = 1.0542855477524427e-10

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-2, 4, 400)

y = f(x)
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.scatter(x_r, f(x_r), color="red", zorder=5) 
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
x0 = -1
points = []
x_r = newton(
    f, x0, args=(points, True), maxiter=100
)  # Método secante
# Out:
# f(-1.0) = -6.0
# f(-1.0002) = -6.002000240008
# f(-0.40007199376044494) = -1.944279357559926
# f(-0.11251734714285737) = -1.1519222942429534
# f(0.3055272738835656) = -0.9459934428847171
# f(2.225935549440168) = -2.6093905298716624
# f(-0.7866314478975496) = -4.129757466766417
# f(7.396374081543759) = 246.90595135720395
# f(-0.6520138337576513) = -3.2045654027231674
# f(-0.5488930782005125) = -2.6181164009056803
# f(-0.08852544084207464) = -1.1127294539448893
# f(0.2517622378613702) = -0.9224326811942098
# f(1.9012514609656634) = -3.0704576412075024
# f(-0.4565827744142934) = -2.1771690842380034
# f(-6.203218352555335) = -361.3423052459625
# f(-0.42174810907673893) = -2.030379466687118
# f(-0.3890785046817195) = -1.9021242675113228
# f(0.09543711518477387) = -0.9310183492475942
# f(0.5599517722463857) = -1.205115558242392
# f(-1.4823668719657201) = -12.33197157683866
# f(0.7811490240949828) = -1.5727800797435725
# f(1.1120300863447232) = -2.2226541121759515
# f(-0.019626383906773105) = -1.0207895287264157
# f(-0.9807854785800442) = -5.810062878841151
# f(0.18523582953509105) = -0.9113452384182965
# f(0.40215953182736575) = -1.017995153649916
# f(-1.668421369861546) = -15.663578528666417
# f(0.5460828750760269) = -1.1856911778685686
# f(0.7274434619457872) = -1.4751343495416005
# f(-0.19685276448867897) = -1.3207340407689894
# f(-8.103245567136156) = -738.1710927137256
# f(-0.18268130892617698) = -1.288895215609276
# f(-0.16882729343768532) = -1.2591472845672094
# f(0.4175746972761696) = -1.0327192591694314
# f(3.0921050623298) = 2.97273203712901
# f(1.1071446889964078) = -2.2130593586367224
# f(1.954235286260948) = -3.0395773366976186
# f(-1.1609992880863749) = -7.769690731089371
# f(3.9560892844991016) = 17.919500804412564
# f(0.38666310516705654) = -1.0040525999988492
# f(0.5760509838213281) = -1.2282994979465076
# f(-0.46131023899698315) = -2.197901759854147
# f(1.8901880472704242) = -3.074960143389549
# f(-6.354147384966214) = -385.0296158921031
# f(1.9565598075862356) = -3.0378610152917913
# f(2.022652263948028) = -2.975796737421716
# f(5.191588127849205) = 63.26055844573372
# f(2.1650228545220394) = -2.748785526032501
# f(2.2910562055044807) = -2.43014619783451
# f(3.2522667077435856) = 4.920551901271763
# f(2.6088331044930224) = -1.0534527633599002
# f(2.7222958393643077) = -0.33574043536894305
# f(2.7753728543717973) = 0.04513857950720812
# f(2.769082612672081) = -0.0015500055017536596
# f(2.769291441216361) = -6.7483132744072805e-06
# f(2.769292354376169) = 1.0165659425354079e-09

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
x0 = -1
points = []
x_r, alg_info = newton(
    f,
    x0,
    args=(points, False),
    maxiter=50,
    disp=False,  
    full_output=True,
)  #  método secante!

# %%
alg_info
# Out:
#       converged: False
#            flag: convergence error
#  function_calls: 52
#      iterations: 50
#            root: 2.7222958393643077
#          method: secant
